# %% [markdown]
# ## Accessing Google Sheets with Pandas
#
# To access a google sheets you must first share the document with "Anyone with the link". Then you will need the sheet id which is the string of letters and numbers preceded by /d/ and followed by /edit.
#
# For example, the sheet 00-InputInformation, where all the information about the Be stars are, has the following url:
#
#
# https://docs.google.com/spreadsheets/d/<span style='color:red'>1M6y1Wnsrc-w5FjUMfKaSFa_-foIDAaMe8W4lYNWnWyk</span>/edit#gid=0
#
# The red text is the sheet id.
#
# You will also need the name of the sheet itself. Below shows how to access the Stars and Observations sheets, but the same process can be followed for any sheet.
#
#
# Note: For some reason this method doesn't keep the column names for every column. Some columns are renamed to "Unnamed: 1" etc.

# %%
import pandas as pd
sheet_id = '1M6y1Wnsrc-w5FjUMfKaSFa_-foIDAaMe8W4lYNWnWyk'
sheet_name = 'Stars'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
StarData=pd.read_csv(url)

sheet_name = 'Observations'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
Observations=pd.read_csv(url)

# %%
StarData
# Out:
#           HD       Name  Nobs      T  log(g)  ModelCode  Adopted-vsini  \
# 0     6226.0     hd6226     1  15000     4.0  T15000g40         120.00
# 1     7636.0     hd7636     2  15000     4.0  T15000g40         220.00
# 2    10144.0    hd10144     1  20000     3.5  T20000g35         245.31
# 3    10516.0    hd10516     1  25000     4.0  T25000g40         382.04
# 4    11415.0    hd11415     1  18000     4.0  T18000g40          48.00
# ..       ...        ...   ...    ...     ...        ...            ...
# 73  217891.0   hd217891     5  15000     3.0  T15000g30          95.00
# 74  221507.0   hd221507     1  10500     4.0  T10500g40          40.00
# 75  224686.0   hd224686     2  13000     4.0  T13000g40         286.16
# 76  239712.0   hd239712     1  21000     4.0  T21000g40         304.86
# 77       NaN  bd-134933     1  30000     4.0  T30000g40         239.56
#
#         Halpha shape                                              Notes  \
# 0         absorption  no disk during observation, rotational modulation
# 1   asymetric single                        binary? no tess observation
# 2               bowl                                 binary or pulsator
# 3   asymetric double  sdO companion https://iopscience.iop.org/artic...
# 4         absorption  not a binary https://iopscience.iop.org/articl...
# ..               ...                                                ...
# 73            single  not a binary https://iopscience.iop.org/articl...
# 74        absorption                                      Not a Be star
# 75             shell                                                NaN
# 76  asymetric double                                                NaN
# 77            single                                                NaN
#
#     BadvsiniFlag  ...  Unnamed: 15  Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0            1.0  ...          NaN          NaN         NaN          NaN
# 1            NaN  ...          NaN          NaN         NaN          NaN
# 2            NaN  ...          NaN          NaN         NaN          NaN
# 3            1.0  ...          NaN          NaN         NaN          NaN
# 4            1.0  ...          NaN          NaN         NaN          NaN
# ..           ...  ...          ...          ...         ...          ...
# 73           1.0  ...          NaN          NaN         NaN          NaN
# 74           1.0  ...          NaN          NaN         NaN          NaN
# 75           1.0  ...          NaN          NaN         NaN          NaN
# 76           NaN  ...          NaN          NaN         NaN          NaN
# 77           1.0  ...          NaN          NaN         NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# ..         ...          ...          ...          ...          ...
# 73         NaN          NaN          NaN          NaN          NaN
# 74         NaN          NaN          NaN          NaN          NaN
# 75         NaN          NaN          NaN          NaN          NaN
# 76         NaN          NaN          NaN          NaN          NaN
# 77         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 24
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 73          NaN
# 74          NaN
# 75          NaN
# 76          NaN
# 77          NaN
#
# [78 rows x 25 columns]

# %%
Observations
# Out:
#        1  Unnamed: 1  Unnamed: 2       Name        LSDfileName     NameAsif  \
# 0    185         1.0           1     hd6226     hd6226_1.lsd.s     hd6226_1
# 1    193         2.0           1     hd7636     hd7636_1.lsd.s     hd7636_1
# 2    194         2.0           2     hd7636     hd7636_2.lsd.s     hd7636_2
# 3      2         3.0           1    hd10144    hd10144_1.lsd.s    hd10144_1
# 4      3         4.0           1    hd10516    hd10516_1.lsd.s    hd10516_1
# ..   ...         ...         ...        ...                ...          ...
# 196  137        74.0           1   hd221507   hd221507_1.lsd.s   hd221507_1
# 197  140        75.0           1   hd224686   hd224686_1.lsd.s   hd224686_1
# 198  141        75.0           2   hd224686   hd224686_2.lsd.s   hd224686_2
# 199  145        76.0           1   hd239712   hd239712_1.lsd.s   hd239712_1
# 200    1        77.0           1  bd-134933  bd-134933_1.lsd.s  bd-134933_1
#
#                           NameOfMask  Unnamed: 7  \
# 0    mask_T15000g40lamb3700_9000.dat           0
# 1    mask_T15000g40lamb3700_9000.dat           0
# 2    mask_T15000g40lamb3700_9000.dat           0
# 3    mask_T20000g35lamb3700_9000.dat           1
# 4    mask_T25000g40lamb3700_9000.dat           0
# ..                               ...         ...
# 196  mask_T10500g40lamb3700_9000.dat           1
# 197  mask_T13000g40lamb3700_9000.dat           1
# 198  mask_T13000g40lamb3700_9000.dat           1
# 199  mask_T21000g40lamb3700_9000.dat           0
# 200  mask_T30000g40lamb3700_9000.dat           0
#
#                      NameOfSymbolicLinkToData  Unnamed: 9  Unnamed: 10  \
# 0                  hd6226_11AP14_1310132pnv.s      110.34   -60.297909
# 1                  hd7636_11AP14_1314767pnv.s      230.00     0.000000
# 2                  hd7636_11AP14_1316457pnv.s      230.00     0.000000
# 3     hd10144_187.D-0917A_2011-12-11_01_pnv.s      245.31    12.981952
# 4                 hd10516_11AP14_1311181pnv.s      382.04   -60.990786
# ..                                        ...         ...          ...
# 196  hd221507_187.D-0917A_2012-07-19_01_pnv.s       20.00     0.000072
# 197  hd224686_187.D-0917A_2011-12-09_01_pnv.s      286.16    11.694301
# 198  hd224686_187.D-0917A_2011-12-12_01_pnv.s      286.16     8.724928
# 199              hd239712_11BP14_1331344pnv.s      304.86    -0.002959
# 200              bd-134933_06BF15_861711pnv.s      239.56    -0.001092
#
#      Unnamed: 11
# 0     -70.000000
# 1       0.000000
# 2       0.000000
# 3      12.981952
# 4     -60.990786
# ..           ...
# 196     0.000072
# 197    11.694301
# 198     8.724928
# 199    -0.002959
# 200    -0.001092
# hd198183
# hd198183
# hd198183
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd202904
# hd203467
# hd203467
# hd205637
# hd205637
# hd209409
# hd209409
# hd212076
# hd212076
# hd212571
# hd214748
# hd216200
# hd216200
# hd216200
# hd217050
# hd217050
# hd217675
# hd217891
# hd217891
# hd217891
# hd217891
# hd217891
# hd221507
# hd224686
# hd224686
# hd239712
# bd-134933

# %%
ObsInfo
# Out:
# 1                                                         1
# Unnamed: 1                                             77.0
# Unnamed: 2                                                1
# Name                                              bd-134933
# LSDfileName                               bd-134933_1.lsd.s
# NameAsif                                        bd-134933_1
# NameOfMask                  mask_T30000g40lamb3700_9000.dat
# Unnamed: 7                                                0
# NameOfSymbolicLinkToData       bd-134933_06BF15_861711pnv.s
# Unnamed: 9                                           239.56
# Unnamed: 10                                       -0.001092
# Unnamed: 11                                       -0.001092
# Name: 200, dtype: object

# %% [markdown]
# We can also loop over every observation of every star by doing:

# %%
for i, StarInfo in StarData.iterrows():
    ObsInfo=Observations[:][StarInfo['Name']==Observations['Name']]
    for j in range(ObsInfo['Name'].size):
        print('{} Observation {}'.format(ObsInfo['Name'].values[j],int(ObsInfo['Unnamed: 2'].values[j])))
# Out:
# hd6226 Observation 1
# hd7636 Observation 1
# hd7636 Observation 2
# hd10144 Observation 1
# hd10516 Observation 1
# hd11415 Observation 1
# hd20336 Observation 1
# hd22192 Observation 1
# hd22192 Observation 2
# hd23302 Observation 1
# hd23302 Observation 2
# hd23630 Observation 1
# hd32343 Observation 1
# hd32343 Observation 2
# hd32991 Observation 1
# hd32991 Observation 2
# hd33328 Observation 1
# hd35411 Observation 1
# hd35411 Observation 2
# hd35411 Observation 3
# hd37202 Observation 1
# hd37202 Observation 2
# hd37795 Observation 1
# hd44506 Observation 1
# hd45725 Observation 1
# hd48917 Observation 1
# hd50013 Observation 1
# hd50209 Observation 1
# hd50209 Observation 2
# hd50209 Observation 3
# hd50209 Observation 4
# hd50209 Observation 5
# hd50209 Observation 6
# hd50820 Observation 1
# hd52918 Observation 1
# hd52918 Observation 2
# hd52918 Observation 3
# hd52918 Observation 4
# hd54309 Observation 1
# hd56139 Observation 1
# hd58050 Observation 1
# hd58050 Observation 2
# hd58343 Observation 1
# hd58343 Observation 2
# hd58715 Observation 1
# hd58715 Observation 2
# hd58715 Observation 3
# hd58715 Observation 4
# hd58715 Observation 5
# hd58715 Observation 6
# hd58978 Observation 1
# hd62367 Observation 1
# hd65875 Observation 1
# hd65875 Observation 2
# hd65875 Observation 3
# hd67698 Observation 1
# hd71072 Observation 1
# hd72067 Observation 1
# hd76838 Observation 1
# hd77320 Observation 1
# hd78764 Observation 1
# hd89884 Observation 1
# hd90966 Observation 1
# hd91120 Observation 1
# hd92938 Observation 1
# hd105435 Observation 1
# hd109387 Observation 1
# hd109387 Observation 2
# hd109387 Observation 3
# hd109387 Observation 4
# hd109387 Observation 5
# hd109387 Observation 6
# hd109387 Observation 7
# hd109387 Observation 8
# hd109387 Observation 9
# hd110335 Observation 1
# hd110432 Observation 1
# hd112091 Observation 1
# hd120324 Observation 1
# hd138749 Observation 1
# hd138749 Observation 2
# hd138749 Observation 3
# hd138749 Observation 4
# hd143275 Observation 1
# hd143275 Observation 2
# hd143275 Observation 3
# hd148184 Observation 1
# hd148184 Observation 2
# hd148184 Observation 3
# hd148184 Observation 4
# hd164284 Observation 1
# hd164284 Observation 2
# hd164284 Observation 3
# hd164284 Observation 4
# hd164284 Observation 5
# hd164284 Observation 6
# hd164284 Observation 7
# hd164284 Observation 8
# hd164284 Observation 9
# hd164284 Observation 10
# hd164284 Observation 11
# hd164284 Observation 12
# hd164284 Observation 13
# hd164284 Observation 14
# hd164284 Observation 15
# hd164284 Observation 16
# hd164284 Observation 17
# hd164284 Observation 18
# hd164284 Observation 19
# hd164284 Observation 20
# hd164284 Observation 21
# hd164906 Observation 1
# hd170783 Observation 1
# hd170783 Observation 2
# hd170783 Observation 3
# hd170783 Observation 4
# hd170783 Observation 5
# hd170783 Observation 6
# hd170783 Observation 7
# hd170783 Observation 8
# hd170783 Observation 9
# hd170783 Observation 10
# hd173948 Observation 1
# hd174237 Observation 1
# hd175869 Observation 1
# hd175869 Observation 2
# hd175869 Observation 3
# hd175869 Observation 4
# hd175869 Observation 5
# hd175869 Observation 6
# hd175869 Observation 7
# hd175869 Observation 8
# hd175869 Observation 9
# hd178175 Observation 1
# hd181231 Observation 1
# hd181231 Observation 2
# hd181231 Observation 3
# hd181231 Observation 4
# hd181231 Observation 5
# hd181231 Observation 6
# hd181231 Observation 7
# hd181231 Observation 8
# hd181231 Observation 9
# hd187567 Observation 1
# hd187811 Observation 1
# hd189687 Observation 1
# hd191610 Observation 1
# hd192685 Observation 1
# hd192685 Observation 2
# hd192685 Observation 3
# hd192685 Observation 4
# hd192685 Observation 5
# hd192685 Observation 6
# hd192685 Observation 7
# hd192685 Observation 8
# hd192685 Observation 9
# hd192685 Observation 10
# hd198183 Observation 1
# hd198183 Observation 2
# hd198183 Observation 3
# hd202904 Observation 1
# hd202904 Observation 2
# hd202904 Observation 3
# hd202904 Observation 4
# hd202904 Observation 5
# hd202904 Observation 6
# hd202904 Observation 7
# hd202904 Observation 8
# hd202904 Observation 9
# hd202904 Observation 10
# hd202904 Observation 11
# hd202904 Observation 12
# hd202904 Observation 13
# hd202904 Observation 14
# hd202904 Observation 15
# hd203467 Observation 1
# hd203467 Observation 2
# hd205637 Observation 1
# hd205637 Observation 2
# hd209409 Observation 1
# hd209409 Observation 2
# hd212076 Observation 1
# hd212076 Observation 2
# hd212571 Observation 1
# hd214748 Observation 1
# hd216200 Observation 1
# hd216200 Observation 2
# hd216200 Observation 3
# hd217050 Observation 1
# hd217050 Observation 2
# hd217675 Observation 1
# hd217891 Observation 1
# hd217891 Observation 2
# hd217891 Observation 3
# hd217891 Observation 4
# hd217891 Observation 5
# hd221507 Observation 1
# hd224686 Observation 1
# hd224686 Observation 2
# hd239712 Observation 1
# bd-134933 Observation 1
